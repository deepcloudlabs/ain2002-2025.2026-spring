# %%
# 1. REST over HTTP -> static
# %matplotlib notebook
import requests
import pandas as pd
import numpy as np
import plotly.express as px

# %%
response = requests.get("https://api.binance.com/api/v3/ticker/price")

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'[{"symbol":"ETHBTC","price":"0.02797000"},{"symbol":"LTCBTC","price":"0.00072100"},{"symbol":"BNBBTC","price":"0.00838800"},{"symbol":"NEOBTC","price":"0.00003542"},{"symbol":"QTUMETH","price":"0.00046550"},{"symbol":"EOSETH","price":"0.00030670"},{"symbol":"SNTETH","price":"0.00001700"},{"symbol":"BNTETH","price":"0.00020260"},{"symbol":"BCCBTC","price":"0.00000000"},{"symbol":"GASBTC","price":"0.00002070"},{"symbol":"BNBETH","price":"0.29980000"},{"symbol":"BTCUSDT","price":"78155.83000000"},{"symbol":"ETHUSDT","price":"2185.95000000"},{"symbol":"HSRBTC","price":"0.00000000"},{"symbol":"OAXETH","price":"0.00000000"},{"symbol":"DNTETH","price":"0.00000000"},{"symbol":"MCOETH","price":"0.00000000"},{"symbol":"ICNETH","price":"0.00000000"},{"symbol":"MCOBTC","price":"0.00000000"},{"symbol":"WTCBTC","price":"0.00000024"},{"symbol":"WTCETH","price":"0.00000000"},{"symbol":"LRCBTC","price":"0.00000052"},{"symbol":"LRCETH","price":"0.00001675"},{"symbol":"QTUMBTC","price":"0.00001628"},{"symbol":"YOYOBTC","price":"0.00000000"},{"symbol":"OMGBTC","price":"0.00003080"},{"symbol":"OMGETH","price":"0.00079100"},{"symbol":"ZRXBTC","price":"0.00000154"},{"symbol":"ZRXETH","price":"0.00009940"},{"symbol":"STRATBTC","price":"0.00000000"},{"symbol":"STRATETH","price":"0.00000000"},{"symbol":"SNGLSBTC","price":"0.00000000"},{"symbol":"SNGLSETH","price":"0.00000000"},{"symbol":"BQXBTC","price":"0.00000000"},{"symbol":"BQXETH","price":"0.00000000"},{"symbol":"KNCBTC","price":"0.00000181"},{"symbol":"KNCETH","price":"0.00039410"},{"symbol":"FUNBTC","price":"0.00000000"},{"symbol":"FUNETH","price":"0.00000146"},{"symbol":"SNMBTC","price":"0.00000057"},{"symbol":"SNMETH","price":"0.00000000"},{"symbol":"NEOETH","price":"0.00477500"},{"symbol":"IOTABTC","price":"0.00000072"},{"symbol":"IOTAETH","price":"0.00003346"},{"symbol":"LINKBTC","price":"0.00012520"},{"symbol":"LINKETH","price":"0.00447900"},{"symbol":"XVGBTC","price":"0.00000000"},{"symbol":"XVGETH","price":"0.00000247"},{"symbol":"SALTBTC","price":"0.00000000"},{"symbol":"SALTETH","price":"0.00000000"},{"symbol":"MDABTC","price":"0.00000000"},{"symbol":"MDAETH","price":"0.00000000"},{"symbol":"MTLBTC","price":"0.00000405"},{"symbol":"MTLETH","price":"0.00068340"},{"symbol":"SUBBTC","price":"0.00000000"},{"symbol":"SUBETH","price":"0.00000000"},{"symbol":"EOSBTC","price":"0.00000716"},{"symbol":"SNTBTC","price":"0.00000032"},{"symbol":"ETCETH","price":"0.00387000"},{"symbol":"ETCBTC","price":"0.00011700"},{"symbol":"MTHBTC","price":"0.00000000"},{"symbol":"MTHETH","price":"0.00000000"},{"symbol":"ENGBTC","price":"0.00000000"},{"symbol":"ENGETH","price":"0.00000000"},{"symbol":"DNTBTC","price":"0.00000186"},{"symbol":"ZECBTC","price":"0.00661100"},{"symbol":"ZECETH","price":"0.23624000"},{"symbol":"BNTBTC","price":"0.00000794"},{"symbol":"ASTBTC","price":"0.00000124"},{"symbol":"ASTETH","price":"0.00000000"},{"symbol":"DASHBTC","price":"0.00053720"},{"symbol":"DASHETH","price":"0.02084000"},{"symbol":"OAXBTC","price":"0.00000038"},{"symbol":"ICNBTC","price":"0.00000000"},{"symbol":"BTGBTC","price":"0.00091300"},{"symbol":"BTGETH","price":"0.00000000"},{"symbol":"EVXBTC","price":"0.00000000"},{"symbol":"EVXETH","price":"0.00000000"},{"symbol":"REQBTC","price":"0.00000112"},{"symbol":"REQETH","price":"0.00000000"},{"symbol":"VIBBTC","price":"0.00000051"},{"symbol":"VIBETH","price":"0.00003450"},{"symbol":"HSRETH","price":"0.00000000"},{"symbol":"TRXBTC","price":"0.00000454"},{"symbol":"TRXETH","price":"0.00016205"},{"symbol":"POWRBTC","price":"0.00000094"},{"symbol":"POWRETH","price":"0.00002760"},{"symbol":"ARKBTC","price":"0.00001679"},{"symbol":"ARKETH","price":"0.00000000"},{"symbol":"YOYOETH","price":"0.00000000"},{"symbol":"XRPBTC","price":"0.00001816"},{"symbol":"XRPETH","price":"0.00064990"},{"symbol":"MODBTC","price":"0.00000000"},{"symbol":"MODETH","price":"0.00000000"},{"symbol":"ENJBTC","price":"0.00000035"},{"symbol":"ENJETH","price":"0.00006172"},{"symbol":"STORJBTC","price":" ...

# %%
tickers = response.json()

# %%
tickers[0:10]
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.02797000'},
#  {'symbol': 'LTCBTC', 'price': '0.00072100'},
#  {'symbol': 'BNBBTC', 'price': '0.00838800'},
#  {'symbol': 'NEOBTC', 'price': '0.00003542'},
#  {'symbol': 'QTUMETH', 'price': '0.00046550'},
#  {'symbol': 'EOSETH', 'price': '0.00030670'},
#  {'symbol': 'SNTETH', 'price': '0.00001700'},
#  {'symbol': 'BNTETH', 'price': '0.00020260'},
#  {'symbol': 'BCCBTC', 'price': '0.00000000'},
#  {'symbol': 'GASBTC', 'price': '0.00002070'}]

# %%
df = pd.DataFrame(tickers)

# %%
df[df.symbol == 'BTCUSDT']
# Out:
#      symbol           price
# 11  BTCUSDT  78155.83000000

# %%
df = pd.read_csv("sample_data/eurostat_hicpv2.csv")

# %%
eu_inflations = df.iloc[6:]

# %%
eu_inflations.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 6 to 40
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   geo     35 non-null     str
#  1   2008    35 non-null     float64
#  2   2009    35 non-null     float64
#  3   2010    35 non-null     float64
#  4   2011    35 non-null     float64
#  5   2012    35 non-null     float64
#  6   2013    35 non-null     float64
#  7   2014    35 non-null     float64
#  8   2015    35 non-null     float64
#  9   2016    35 non-null     float64
#  10  2017    35 non-null     float64
#  11  2018    35 non-null     float64
#  12  2019    35 non-null     float64
# dtypes: float64(12), str(1)
# memory usage: 3.7 KB

# %%
eu_inflations
# Out:
#                 geo  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 6           Belgium   4.5   0.0   2.3   3.4   2.6   1.2   0.5   0.6   1.8
# 7          Bulgaria  12.0   2.5   3.0   3.4   2.4   0.4  -1.6  -1.1  -1.3
# 8           Czechia   6.3   0.6   1.2   2.2   3.5   1.4   0.4   0.3   0.6
# 9           Denmark   3.6   1.0   2.2   2.7   2.4   0.5   0.4   0.2   0.0
# 10          Germany   2.8   0.2   1.1   2.5   2.2   1.6   0.8   0.7   0.4
# 11          Estonia  10.6   0.2   2.7   5.1   4.2   3.2   0.5   0.1   0.8
# 12          Ireland   3.1  -1.7  -1.6   1.2   1.9   0.5   0.3   0.0  -0.2
# 13           Greece   4.2   1.3   4.7   3.1   1.0  -0.9  -1.4  -1.1   0.0
# 14            Spain   4.1  -0.2   2.0   3.0   2.4   1.5  -0.2  -0.6  -0.3
# 15           France   3.2   0.1   1.7   2.3   2.2   1.0   0.6   0.1   0.3
# 16          Croatia   5.8   2.2   1.1   2.2   3.4   2.3   0.2  -0.3  -0.6
# 17            Italy   3.5   0.8   1.6   2.9   3.3   1.2   0.2   0.1  -0.1
# 18           Cyprus   4.4   0.2   2.6   3.5   3.1   0.4  -0.3  -1.5  -1.2
# 19           Latvia  15.3   3.3  -1.2   4.2   2.3   0.0   0.7   0.2   0.1
# 20        Lithuania  11.1   4.2   1.2   4.1   3.2   1.2   0.2  -0.7   0.7
# 21       Luxembourg   4.1   0.0   2.8   3.7   2.9   1.7   0.7   0.1   0.0
# 22          Hungary   6.0   4.0   4.7   3.9   5.7   1.7   0.0   0.1   0.4
# 23            Malta   4.7   1.8   2.0   2.5   3.2   1.0   0.8   1.2   0.9
# 24      Netherlands   2.2   1.0   0.9   2.5   2.8   2.6   0.3   0.2   0.1
# 25          Austria   3.2   0.4   1.7   3.6   2.6   2.1   1.5   0.8   1.0
# 26           Poland   4.2   4.0   2.6   3.9   3.7   0.8   0.1  -0.7  -0.2
# 27         Portugal   2.7  -0.9   1.4   3.6   2.8   0.4  -0.2   0.5   0.6
# 28          Romania   7.9   5.6   6.1   5.8   3.4   3.2   1.4  -0.4  -1.1
# 29         Slovenia   5.5   0.8   2.1   2.1   2.8   1.9   0.4  -0.8  -0.2
# 30         Slovakia   3.9   0.9   0.7   4.1   3.7   1.5  -0.1  -0.3  -0.5
# 31          Finland   3.9   1.6   1.7   3.3   3.2   2.2   1.2  -0.2   0.4
# 32           Sweden   3.3   1.9   1.9   1.4   0.9   0.4   0.2   0.7   1.1
# 33   United Kingdom   3.6   2.2   3.3   4.5   2.8   2.6   1.5   0.0   0.7
# 34          Iceland  12.8  16.3   7.5   4.2   6.0   4.1   1.0   0.3   0.8
# 35           Norway   3.4   2.3   2.3   1.3   0.4   2.0   1.9   2.0   3.9
# 36      Switzerland   2.4  -0.7   0.6   0.1  -0.7   0.1   0.0  -0.8  -0.5
# 37  North Macedonia   7.6  -0.1   1.1   3.2   1.8   2.7   0.0   0.1   0.2
# 38           Serbia  11.9   8.2   6.2  11.2   7.4   7.7   2.3   1.5   1.3
# 39           Turkey  10.4   6.3   8.6   6.5   9.0   7.5   8.9   7.7   7.7
# 40    United States   4.4  -0.8   2.6   3.9   2.2   1.3   1.3  -0.8   0.5
#
#     2017  2018  2019
# 6    2.2   2.3   1.2
# 7    1.2   2.6   2.5
# 8    2.4   2.0   2.6
# 9    1.1   0.7   0.7
# 10   1.7   1.9   1.4
# 11   3.7   3.4   2.3
# 12   0.3   0.7   0.9
# 13   1.1   0.8   0.5
# 14   2.0   1.7   0.8
# 15   1.2   2.1   1.3
# 16   1.3   1.6   0.8
# 17   1.3   1.2   0.6
# 18   0.7   0.8   0.5
# 19   2.9   2.6   2.7
# 20   3.7   2.5   2.2
# 21   2.1   2.0   1.6
# 22   2.4   2.9   3.4
# 23   1.3   1.7   1.5
# 24   1.3   1.6   2.7
# 25   2.2   2.1   1.5
# 26   1.6   1.2   2.1
# 27   1.6   1.2   0.3
# 28   1.1   4.1   3.9
# 29   1.6   1.9   1.7
# 30   1.4   2.5   2.8
# 31   0.8   1.2   1.1
# 32   1.9   2.0   1.7
# 33   2.7   2.5   1.8
# 34  -1.7   0.7   2.0
# 35   1.9   3.0   2.3
# 36   0.6   0.9   0.4
# 37   2.1   2.3   0.7
# 38   3.3   2.0   1.9
# 39  11.1  16.3  15.2
# 40   1.7   2.2   1.3

# %%
years = eu_inflations.columns.to_list()[1:]

# %%
inflations = pd.melt(frame=eu_inflations, id_vars='geo', value_vars=years, var_name="years", value_name="inflation_rate")

# %%
covid19_df = pd.json_normalize(pd.read_json("sample_data/covid19-stream-data.json")['records'])

# %%
covid19_df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='str')

# %%
covid19_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  str
#  1   day                                                         61900 non-null  str
#  2   month                                                       61900 non-null  str
#  3   year                                                        61900 non-null  str
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  str
#  7   geoId                                                       61900 non-null  str
#  8   countryterritoryCode                                        61777 non-null  str
#  9   popData2019                                                 61777 non-null  float64
#  10  continentExp                                                61900 non-null  str
#  11  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  61900 non-null  str
# dtypes: float64(1), int64(2), str(9)
# memory usage: 5.7 MB

# %%
covid19_df.describe()
# Out:
#                cases        deaths   popData2019
# count   61900.000000  61900.000000  6.177700e+04
# mean     1155.147237     26.055460  4.098770e+07
# std      6779.224479    131.227055  1.531294e+08
# min     -8261.000000  -1918.000000  8.150000e+02
# 25%         0.000000      0.000000  1.293120e+06
# 50%        15.000000      0.000000  7.169456e+06
# 75%       273.000000      4.000000  2.851583e+07
# max    234633.000000   4928.000000  1.433784e+09

# %%
turkish_covid_results = covid19_df[covid19_df.countryterritoryCode == 'TUR']

# %%
turkish_covid_results.to_csv("sample_data/turkish-covid19.csv")

# %%
turkish_covid_results.to_json("sample_data/turkish-covid19.json")

# %%
# %pip install openpyxl
turkish_covid_results.to_excel("sample_data/turkish-covid19.xlsx")
# Out:
# Requirement already satisfied: openpyxl in .\.venv\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in .\.venv\Lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
